# %% [markdown]
# # Estimating Burned Area Using RSensePy

# %% [markdown]
# This notebook introduces the biophyical indexcalculator, RSensePy and guides users on how to calculate one of the increasingly available vegetation indices therein.

# %% [markdown]
# ### CASE 1 - Mapping Maui's Wildfires.

# %% [markdown]
# Between August 7th and 9th, Hurricane Dora, a Category 4 storm, with max wind speeds above 130 miles per hour, passed by Hawaii. At approximatly 3:00am on August 8th, brush fire was reported in the Olinda Road area of Kula, an area in central Maui. Fueled by the severe storms from Dora, this fire as well as others like it would spring up across parts of West and Central Maui, raging on for 4 days. The aftermath would see over 100 people dead, an estimated 2200 building destroyed, and much of the touristic and economic hub of Lahaina, on the island’s western edge, reduced to ashes.
#
# The internet is filled with shpocking images of this devastation, mostly provided by on ground reporters and affected residents. Using Remote sening, by way of freely available Landsat 9 imagery, and the RSensePy biophysical Index calculator, we will now visulaize the damage caused especially in Lahaina, the area worst hit.
#
# For more details on RSensePy and how to use it, please read the docs. (https://rsensepy.readthedocs.io/en/latest/installation.html)

# %%
pip install RSensePy

# %%
import RSensePy as rp

# %%
before= rp.L8("C://test//LC08_L2SP_063046_20230807_20230812_02_T1")
after= rp.L8("C://test//LC09_L2SP_063046_20230815_20230817_02_T1")

# %% [markdown]
# Getting the metadat is quite straightforward, just call the meta method.

# %%
before.meta()
# Out:
# 					Mission = L
#
# 					Sensor = C
#
# 					Satellite= 08
#
# 					Correction Level = L2SP
#
# 					Path = 063
#
# 					Row = 046
#
# 					Acquisition Date = 20230807
#
# 					Processing Data = 20230812
#
# 					Collection Number = 02
#
# 					Collection Category = T1

# %%
after.meta()
# Out:
# 					Mission = L
#
# 					Sensor = C
#
# 					Satellite= 09
#
# 					Correction Level = L2SP
#
# 					Path = 063
#
# 					Row = 046
#
# 					Acquisition Date = 20230815
#
# 					Processing Data = 20230817
#
# 					Collection Number = 02
#
# 					Collection Category = T1

# %% [markdown]
# From the metadata, we see the acquisition/sensing date for the before image is 7th of August, before the fire startes, while the after image is acquired on the 15th of August after the fires have sucessfully been put out.

# %%
#set bounding box, within which the procesising and output will be clipped. 
#An alternative is to use a pre-existing shapefile

lahainashp= "C:/test/lahania.shp"
beforeNBR= "C:/test/output/beforeNBR.tif" #output folder should be created a-priori

#calling the NBR method to calculate the Normalied Burn Ratio.
before.NBR(cloud=True, save_location=beforeNBR, shp_location=lahainashp, visualise=True)
# Out:
# cloudMask calculation completed
# normDifVal calculation completed
# Writing raster completed
# C:\Users\xeon\AppData\Roaming\Python\Python39\site-packages\RSensePy\__init__.py:193: RuntimeWarning: invalid value encountered in true_divide
#   normDifVal = numerator / denominator

# %%
afterNBR= "C:/test/output/afterNBR.tif"

#calling the NBR method to calculate the Normalied Burn Ratio.
after.NBR(cloud=True, save_location=afterNBR, shp_location=lahainashp, visualise=True)
# Out:
# cloudMask calculation completed
# normDifVal calculation completed
# Writing raster completed
# C:\Users\xeon\AppData\Roaming\Python\Python39\site-packages\RSensePy\__init__.py:193: RuntimeWarning: invalid value encountered in true_divide
#   normDifVal = numerator / denominator

# %%
#calculating the difference
! pip install rasterio
# Out:
# Requirement already satisfied: rasterio in c:\users\xeon\miniconda3\lib\site-packages (1.3.6)
# Requirement already satisfied: affine in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.18 in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (1.22.3)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\xeon\miniconda3\lib\site-packages (from rasterio) (65.6.3)
# Requirement already satisfied: colorama in c:\users\xeon\miniconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\xeon\miniconda3\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)

# %%
import rasterio as rio
import numpy as np

# %%
#calculating the differnce between before and after images

pre_nbr= rio.open(beforeNBR)
post_nbr= rio.open(afterNBR)

pre= pre_nbr.read()
post= post_nbr.read()

diffNBR= post.astype(rio.float32) - pre.astype(rio.float32)

meta = pre_nbr.meta
meta.update(driver='GTiff')
meta.update(dtype=rio.float32)

#saving the differnce to file

diffNBR_path = 'C:/test/output/diffNBR.tif'

with rio.open(diffNBR_path, 'w', **meta) as dest:
    dest.write(diffNBR.astype(rio.float32))
# Out:
# (1, 212, 172)

# %%
#visualising the calculated difference

import matplotlib.pyplot as plt

img = rio.open(diffNBR_path)
img_r = img.read()
diffNBR_img = np.asarray(img_r)

plt.figure(figsize=(10, 10))
plt.imshow(img_r.squeeze(), cmap='RdYlGn')
plt.title("Difference NBR")
plt.colorbar()
plt.show()

#img = rio.open(diffNBR_path)
#img_r = img.read()
#diffNBR_img = np.asarray(img_r)

# %% [markdown]
# ### CASE 2 Mapping Euboea's Wildfires
#
# Rising global tempratures and geogrpahy makes Greece prone to severe heatwaves and wildfires. This chronic yearly phenomena continues to cause devastation across the country where tempratures constantly exceed 40 degrees celcius in the summer. 2023 is no exception with wildfires being reported since July. Over 80 fires have been recorded, with at least 35 dead as at August 2023.
#
# Similar situations were observed in 2021 as well, where Greece experience the worst wildfires since 2007. One of the areas chronicly affected Euboea(EVia), the second most populus island in Greece. More than a third of land area detroyed by the 2021 Greece wildfires were in Northern Euboea. We will now go on to visulaize this area using RSensepy and Sentinel 2 Imagery.
#
# To use Sentinel 2 imagery with RSensePy, it is important to check the following
#
# * The imagery files are located within the current working directory
# * The Sentinel 2 product folder contains only the relevant resolution folder (e.g. if 20m resolution is being used, delete the other 10 and 60 meter folders).
# or
# * Extract just the relevant resolution folder into a parent folder with the same name as the downloaded sentinel 2 product.
#
# Also, Sentinel 2 cloud masking is not currently implememted. Therefore, it is adviced to use imagery with below 10% cloud cover as not to cause misleading results. The cloud masking implementation is currenlty underway and will be implemented soon.

# %%
beforeS2 = rp.S2("C://test//S2B_MSIL2A_20210801T092029_N0301_R093_T34SFJ_20210801T114000.SAFE")
afterS2 = rp.S2("C://test//S2A_MSIL2A_20210925T092031_N0301_R093_T34SFJ_20210925T124522.SAFE")

# %%
beforeS2.meta()
# Out:
# 					Mission = S2B
#
# 					Product Level = MSIL2A
#
# 					Sensing Date= 20210801T092029
#
# 					Base Number = N0301
#
# 					Relative Orbit Number = R093
#
# 					Tile Number Field = T34SFJ
#
# 					Product description = 20210801T114000
#
# 					Product Format = SAFE

# %%
afterS2.meta()
# Out:
# 					Mission = S2A
#
# 					Product Level = MSIL2A
#
# 					Sensing Date= 20210925T092031
#
# 					Base Number = N0301
#
# 					Relative Orbit Number = R093
#
# 					Tile Number Field = T34SFJ
#
# 					Product description = 20210925T124522
#
# 					Product Format = SAFE

# %%
Euboeashp= "C:/test/Euboea.shp"
beforeS2NBR= "C:/test/output/beforeS2NBR.tif" #output folder should be created a-priori

#calling the NBR method to calculate the Normalied Burn Ratio.
beforeS2.NBR(save_location=beforeS2NBR, shp_location=Euboeashp, visualise=True)
# Out:
# C:\Users\xeon\AppData\Roaming\Python\Python39\site-packages\RSensePy\__init__.py:819: RuntimeWarning: invalid value encountered in true_divide
#   normDifVal = numerator / denominator

# %%
afterS2NBR= "C:/test/output/afterS2NBR.tif" #output folder should be created a-priori

#calling the NBR method to calculate the Normalied Burn Ratio.
afterS2.NBR(save_location=afterS2NBR, shp_location=Euboeashp, visualise=True)
# Out:
# C:\Users\xeon\AppData\Roaming\Python\Python39\site-packages\RSensePy\__init__.py:819: RuntimeWarning: invalid value encountered in true_divide
#   normDifVal = numerator / denominator

# %%
#calculating the differnce between before and after images

pre_nbrs2= rio.open(beforeS2NBR)
post_nbrs2= rio.open(afterS2NBR)

preE= pre_nbrs2.read()
postE= post_nbrs2.read()

diffNBRS2= postE.astype(rio.float32) - preE.astype(rio.float32)

metaE = pre_nbrs2.meta
metaE.update(driver='GTiff')
metasE.update(dtype=rio.float32)

#saving the differnce to file

diffNBRS2_path = 'C:/test/output/diffNBRs2.tif'

with rio.open(diffNBRS2_path, 'w', **meta) as dest:
    dest.write(diffNBRS2.astype(rio.float32))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41592\1119781850.py in <cell line: 9>()
#       7 postE= post_nbrs2.read()
#       8
# ----> 9 diffNBRS2= postE.astype(rio.float32) - preE.astype(rio.float32)
#      10
#      11 metaE = pre_nbrs2.meta
#
# ValueError: operands could not be broadcast together with shapes (1,3329,2927) (1,1110,977)
